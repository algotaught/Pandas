# %% [raw]
# '''Used for data manipulation and various other data operations
# we can use excel also for these tasks but excel cannot handle big files
# '''

# %% [raw]
# Topics
# Read and Write Operations
#
# csv
#
# tsv
#
# excel
#
# html
#
# github dataset
#
# nrows
#
# Customer Delimiter
#
# Header removal
#
# Custom column names
#
# skipping rows
#
# saving df as csv or extra
#
#
#
# Data Exploration
#
# Present Working Directory
#
# Type df
#
# Shape
#
# data type
#
# head
#
# tail
#
# describe
#
# filter operation
#
# describe object type of data
#
# unique
#
# nunique
#
# isnull
#
# sum of isnull
#
# setting custom null values
#
# Column extraction
#
# DataType of column
#
# MUltiple column extraction
#
# delete a column
#
# Column extraction based on conditions
#
# sorting dataframe based on column
#
# .loc
#
# .iloc
#
# Data Manipulation
#
# Converting the datatype of a column
#
# creating new column
#
# mapping

# %% [markdown]
# # importing pandas library

# %%
import pandas as pd

# %% [markdown]
# # Loading files using Pandas

# %% [markdown]
# ## loading csv data into pandas

# %%
dataset=pd.read_csv('iris.csv')

# %%
dataset
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#stores everything in tabular format 
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
#reading a tab saperated file
dataset=pd.read_csv('iris.tsv',sep='\t')

# %%
dataset
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#reading data with some other delimiter
pd.read_csv('Book1.csv',sep='|')
# Out:
#                                  What is corona virus  \
# 0                                    What is COVID-19
# 1                  What are the symptoms of COVID-19
# 2                            How does COVID-19 spread
# 3   Can the virus that causes COVID-19 be transmit...
# 4   Can CoVID-19 be caught from a person who has n...
# 5   Can I catch COVID-19 from the feces of someone...
# 6   What can I do to protect myself and prevent th...
# 7                 How likely am I to catch COVID-19?
# 8                     Should I worry about COVID-19?
# 9        Who is at risk of developing severe illness
# 10  Are antibiotics effective in preventing or tre...
# 11  Are there any medicines or therapies that can ...
# 12  Is there a vaccine drug or treatment for COVID...
# 13                      Is COVID-19 the same as SARS?
# 14              Should I wear mask to protect myself
# 15  How to put on use take off and dispose of a mask?
# ...

# %%
#Loading data from excel file
pd.read_excel('Book1.xlsx')
# Out:
#    1  2  3  4
# 0  5  6  7  8

# %%
#loading excel data for specific sheet
pd.read_excel('Book1.xlsx',sheet_name='Sheet2',header=None)
# Out:
#      0   1   2   3
# 0    9  10  11  12
# 1  113  14  15  16

# %%
df=pd.read_html('https://www.mohfw.gov.in/')

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [Empty DataFrame
#  Columns: [(S. No., S. No.), (Name of State / UT, Name of State / UT), (Active Cases*, Total), (Active Cases*, Change since yesterdayChange since yesterday), (Cured/Discharged/Migrated*, Cumulative), (Cured/Discharged/Migrated*, Change since yesterday), (Deaths**, Cumulative), (Deaths**, Change since yesterday)]
#  Index: []]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df[0]
# Out:
# Empty DataFrame
# Columns: [(S. No., S. No.), (Name of State / UT, Name of State / UT), (Active Cases*, Total), (Active Cases*, Change since yesterdayChange since yesterday), (Cured/Discharged/Migrated*, Cumulative), (Cured/Discharged/Migrated*, Change since yesterday), (Deaths**, Cumulative), (Deaths**, Change since yesterday)]
# Index: []

# %%
pd.read_csv('mavo.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 3: unexpected end of data
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-15-d342daca03d8> in <module>
# ----> 1 pd.read_csv('mavo.csv')
#
# ...

# %%
pd.read_csv('mavo.csv',encoding='latin')
# Out:
#      Application ID Current City  \
# 0            MS0001         Pune
# 1            MS0002         Pune
# 2            MS0003  Navi Mumbai
# 3            MS0004    Bangalore
# 4            MS0005       Mumbai
# ...             ...          ...
# 2163         MS2164    Hyderabad
# 2164         MS2165    Bangalore
# 2165         MS2166       Nagpur
# 2166         MS2167       Kanpur
# 2167         MS2168     Durgapur
#
#                                            Other skills  \
# 0                              Machine Learning, Python
# 1                              Machine Learning, Python
# 2     Data Analytics, Data Science, Machine Learning...
# 3     Data Analytics, Algorithms, C Programming, Dat...
# 4     Artifical Intelligence, Computer Vision, Deep ...
# ...                                                 ...
# 2163  Database Management System (DBMS), HTML, Pytho...
# 2164  CSS, Cloud Computing, HTML, PHP, Python, Andro...
# ...

# %%
#reading github dataset

# %%
pd.read_csv('https://raw.githubusercontent.com/ashishpatel26/Titanic-Machine-Learning-from-Disaster/master/input/test.csv')
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
#setting limit to how many rows are loaded
pd.read_csv('https://raw.githubusercontent.com/ashishpatel26/Titanic-Machine-Learning-from-Disaster/master/input/test.csv',nrows=400)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                                ...
# 395         1287       1     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 396         1288       3                               Colbert, Mr. Patrick
# 397         1289       1  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...
# 398         1290       3                     Larsson-Rondberg, Mr. Edvard A
# 399         1291       3                           Conlon, Mr. Thomas Henry
#
# ...

# %%
#skip error causing rows
pd.read_csv('error (2).csv', skiprows=[2,4])
# Out:
#      1    2      3     4  Unnamed: 4  Unnamed: 5
# 0  one  two  three  four         NaN         NaN
# 1   12   13     14    15         NaN         NaN
# 2   10   11     14    15         NaN         NaN

# %%
pd.read_csv('error (2).csv')
# Out:
#                              1      2      3      4 Unnamed: 4 Unnamed: 5
# 0                          one    two  three   four        NaN        NaN
# 1  error error errroroereroror    NaN    NaN    NaN        NaN        NaN
# 2                           12     13     14     15        NaN        NaN
# 3  error error errroroereroror  error  error  error      error      error
# 4                           10     11     14     15        NaN        NaN

# %% [raw]
# '''manipulating the headings,
# by default header will be the first row'''

# %%
dataset
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#removing headers/columns
pd.read_csv('iris.csv',header=None)
# Out:
#                 0            1             2            3               4
# 0    sepal length  sepal width  petal length  petal width           class
# 1             5.1          3.5           1.4          0.2     Iris-setosa
# 2             4.9            3           1.4          0.2     Iris-setosa
# 3             4.7          3.2           1.3          0.2     Iris-setosa
# 4             4.6          3.1           1.5          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 146           6.7            3           5.2          2.3  Iris-virginica
# 147           6.3          2.5             5          1.9  Iris-virginica
# 148           6.5            3           5.2            2  Iris-virginica
# 149           6.2          3.4           5.4          2.3  Iris-virginica
# 150           5.9            3           5.1          1.8  Iris-virginica
#
# [151 rows x 5 columns]

# %%
#giving custom column names
pd.read_csv('iris.csv')
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dataset=pd.read_csv('iris.csv',names=['Header1','header2','header3','header4','header5'])

# %%
dataset
# Out:
#           Header1      header2       header3      header4         header5
# 0    sepal length  sepal width  petal length  petal width           class
# 1             5.1          3.5           1.4          0.2     Iris-setosa
# 2             4.9            3           1.4          0.2     Iris-setosa
# 3             4.7          3.2           1.3          0.2     Iris-setosa
# 4             4.6          3.1           1.5          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 146           6.7            3           5.2          2.3  Iris-virginica
# 147           6.3          2.5             5          1.9  Iris-virginica
# 148           6.5            3           5.2            2  Iris-virginica
# 149           6.2          3.4           5.4          2.3  Iris-virginica
# 150           5.9            3           5.1          1.8  Iris-virginica
#
# [151 rows x 5 columns]

# %%
#what if you give extra header?
dataset=pd.read_csv('iris.csv',names=['Header1','header2','header3','header4','header5','header6'])

# %%
dataset
# Out:
#           Header1      header2       header3      header4         header5  \
# 0    sepal length  sepal width  petal length  petal width           class
# 1             5.1          3.5           1.4          0.2     Iris-setosa
# 2             4.9            3           1.4          0.2     Iris-setosa
# 3             4.7          3.2           1.3          0.2     Iris-setosa
# 4             4.6          3.1           1.5          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 146           6.7            3           5.2          2.3  Iris-virginica
# 147           6.3          2.5             5          1.9  Iris-virginica
# 148           6.5            3           5.2            2  Iris-virginica
# 149           6.2          3.4           5.4          2.3  Iris-virginica
# 150           5.9            3           5.1          1.8  Iris-virginica
#
#      header6
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# ...

# %%
#saving data
dataset.to_csv('iris_custom.csv')

# %%
#giving custom separator
dataset.to_csv('iris_@.csv',sep='%')

# %%
#representation operation for null values
dataset.to_excel('iris.xlsx',na_rep='empty')

# %%
#saving without index or headers
dataset.to_csv('iris_noheaders.csv',index=False, header=False)

# %% [markdown]
# # Data exploration

# %%
# present working directory 
import os
os.getcwd()
# Out:
# 'C:\\Users\\utkarsh'

# %%
# shape of dataset
dataset.shape
# Out:
# (151, 6)

# %%
dataset.dtypes
# Out:
# Header1     object
# header2     object
# header3     object
# header4     object
# header5     object
# header6    float64
# dtype: object

# %%
#head and tail

# %%
dataset.head()
# Out:
#         Header1      header2       header3      header4      header5  header6
# 0  sepal length  sepal width  petal length  petal width        class      NaN
# 1           5.1          3.5           1.4          0.2  Iris-setosa      NaN
# 2           4.9            3           1.4          0.2  Iris-setosa      NaN
# 3           4.7          3.2           1.3          0.2  Iris-setosa      NaN
# 4           4.6          3.1           1.5          0.2  Iris-setosa      NaN

# %%
dataset.tail()
# Out:
#     Header1 header2 header3 header4         header5  header6
# 146     6.7       3     5.2     2.3  Iris-virginica      NaN
# 147     6.3     2.5       5     1.9  Iris-virginica      NaN
# 148     6.5       3     5.2       2  Iris-virginica      NaN
# 149     6.2     3.4     5.4     2.3  Iris-virginica      NaN
# 150     5.9       3     5.1     1.8  Iris-virginica      NaN

# %%
dataset.head(10)
# Out:
#         Header1      header2       header3      header4      header5  header6
# 0  sepal length  sepal width  petal length  petal width        class      NaN
# 1           5.1          3.5           1.4          0.2  Iris-setosa      NaN
# 2           4.9            3           1.4          0.2  Iris-setosa      NaN
# 3           4.7          3.2           1.3          0.2  Iris-setosa      NaN
# 4           4.6          3.1           1.5          0.2  Iris-setosa      NaN
# 5             5          3.6           1.4          0.2  Iris-setosa      NaN
# 6           5.4          3.9           1.7          0.4  Iris-setosa      NaN
# 7           4.6          3.4           1.4          0.3  Iris-setosa      NaN
# 8             5          3.4           1.5          0.2  Iris-setosa      NaN
# 9           4.4          2.9           1.4          0.2  Iris-setosa      NaN

# %%
dataset.tail(10)
# Out:
#     Header1 header2 header3 header4         header5  header6
# 141     6.7     3.1     5.6     2.4  Iris-virginica      NaN
# 142     6.9     3.1     5.1     2.3  Iris-virginica      NaN
# 143     5.8     2.7     5.1     1.9  Iris-virginica      NaN
# 144     6.8     3.2     5.9     2.3  Iris-virginica      NaN
# 145     6.7     3.3     5.7     2.5  Iris-virginica      NaN
# 146     6.7       3     5.2     2.3  Iris-virginica      NaN
# 147     6.3     2.5       5     1.9  Iris-virginica      NaN
# 148     6.5       3     5.2       2  Iris-virginica      NaN
# 149     6.2     3.4     5.4     2.3  Iris-virginica      NaN
# 150     5.9       3     5.1     1.8  Iris-virginica      NaN

# %% [raw]
# stats of dataset
#
# .describe()
# will give statistics about the numerical columns of our dataset
# count: total number of rows not counting the rows having null values
#
# mean: average of the data present in the column
#
# standard deviation: deviation from the mean
#
# minimum: minimum value present in the column
#
# 25,50,75%: data sorted in ascending order and then values are given.

# %%
dataset.describe()
# Out:
#        header6
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df=pd.read_csv('titanic.csv')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#writing the filter condition
df.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
#applying the condition on dataset
df.dtypes[df.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
#extracting the index value of the data having only obejct type of data by using .index command
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
#getting description of object type of data
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#                           Name   Sex    Ticket    Cabin Embarked
# count                      891   891       891      204      889
# unique                     891     2       681      147        3
# top     Hunt, Mr. George Henry  male  CA. 2343  B96 B98        S
# freq                         1   577         7        4      644

# %%
#single column is always a series and more than one columns are dataframe object.

# %%
#unique and nunique function

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked'].nunique()
# Out:
# 3

# %%
#null values filter

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
#aggregating all the null values to get the sum
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data=pd.read_csv('iris.csv')
data
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# class           0
# dtype: int64

# %%
#setting custom null datapoints
data=pd.read_csv('iris.csv',na_values=[3, 'Iris-setosa'])

# %%
data
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2             NaN
# 1             4.9          NaN           1.4          0.2             NaN
# 2             4.7          3.2           1.3          0.2             NaN
# 3             4.6          3.1           1.5          0.2             NaN
# 4             5.0          3.6           1.4          0.2             NaN
# ..            ...          ...           ...          ...             ...
# 145           6.7          NaN           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          NaN           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          NaN           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.isnull()
# Out:
#      sepal length  sepal width  petal length  petal width  class
# 0           False        False         False        False   True
# 1           False         True         False        False   True
# 2           False        False         False        False   True
# 3           False        False         False        False   True
# 4           False        False         False        False   True
# ..            ...          ...           ...          ...    ...
# 145         False         True         False        False  False
# 146         False        False         False        False  False
# 147         False         True         False        False  False
# 148         False        False         False        False  False
# 149         False         True         False        False  False
#
# [150 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# sepal length     0
# sepal width     26
# petal length     1
# petal width      0
# class           50
# dtype: int64

# %%
#extracting data of a particular column
data['sepal length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length, Length: 150, dtype: float64

# %%
#extracting 2 columns
data[['sepal length', 'petal length']]
# Out:
#      sepal length  petal length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]

# %%
#what is the datatype of one column vs 2 columns
type(data['sepal length'])
# Out:
# pandas.core.series.Series

# %%
type(data[['sepal length', 'petal length']])
# Out:
# pandas.core.frame.DataFrame

# %%
#deleting a column
del data['sepal length']

# %%
data
# Out:
#      sepal width  petal length  petal width           class
# 0            3.5           1.4          0.2             NaN
# 1            NaN           1.4          0.2             NaN
# 2            3.2           1.3          0.2             NaN
# 3            3.1           1.5          0.2             NaN
# 4            3.6           1.4          0.2             NaN
# ..           ...           ...          ...             ...
# 145          NaN           5.2          2.3  Iris-virginica
# 146          2.5           5.0          1.9  Iris-virginica
# 147          NaN           5.2          2.0  Iris-virginica
# 148          3.4           5.4          2.3  Iris-virginica
# 149          NaN           5.1          1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %%
data.drop('sepal width',axis=1)
# Out:
#      petal length  petal width           class
# 0             1.4          0.2             NaN
# 1             1.4          0.2             NaN
# 2             1.3          0.2             NaN
# 3             1.5          0.2             NaN
# 4             1.4          0.2             NaN
# ..            ...          ...             ...
# 145           5.2          2.3  Iris-virginica
# 146           5.0          1.9  Iris-virginica
# 147           5.2          2.0  Iris-virginica
# 148           5.4          2.3  Iris-virginica
# 149           5.1          1.8  Iris-virginica
#
# [150 rows x 3 columns]

# %%
#axis=1 for column operations and axis=0 for row operations

# %%
data
# Out:
#      sepal width  petal length  petal width           class
# 0            3.5           1.4          0.2             NaN
# 1            NaN           1.4          0.2             NaN
# 2            3.2           1.3          0.2             NaN
# 3            3.1           1.5          0.2             NaN
# 4            3.6           1.4          0.2             NaN
# ..           ...           ...          ...             ...
# 145          NaN           5.2          2.3  Iris-virginica
# 146          2.5           5.0          1.9  Iris-virginica
# 147          NaN           5.2          2.0  Iris-virginica
# 148          3.4           5.4          2.3  Iris-virginica
# 149          NaN           5.1          1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %%
#inplace=True
data.drop('sepal width', axis=1, inplace=True)

# %%
data
# Out:
#      petal length  petal width           class
# 0             1.4          0.2             NaN
# 1             1.4          0.2             NaN
# 2             1.3          0.2             NaN
# 3             1.5          0.2             NaN
# 4             1.4          0.2             NaN
# ..            ...          ...             ...
# 145           5.2          2.3  Iris-virginica
# 146           5.0          1.9  Iris-virginica
# 147           5.2          2.0  Iris-virginica
# 148           5.4          2.3  Iris-virginica
# 149           5.1          1.8  Iris-virginica
#
# [150 rows x 3 columns]

# %%
#droppping multiple columms
data=pd.read_csv('iris.csv')

# %%
data
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.drop(['sepal length', 'sepal width'],axis=1, inplace=True)

# %%
data
# Out:
#      petal length  petal width           class
# 0             1.4          0.2     Iris-setosa
# 1             1.4          0.2     Iris-setosa
# 2             1.3          0.2     Iris-setosa
# 3             1.5          0.2     Iris-setosa
# 4             1.4          0.2     Iris-setosa
# ..            ...          ...             ...
# 145           5.2          2.3  Iris-virginica
# 146           5.0          1.9  Iris-virginica
# 147           5.2          2.0  Iris-virginica
# 148           5.4          2.3  Iris-virginica
# 149           5.1          1.8  Iris-virginica
#
# [150 rows x 3 columns]

# %%
#column extraction based on conditions

# %%
df=pd.read_csv('titanic.csv')

# %%
#give the condition filter
df['Sex']=='male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
#apply the condition filter
df[df['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#filterting based on multiple conditions
df[(df.Sex=='male') & (df.Age>20)]
# Out:
#      PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 0              1         0       3        Braund, Mr. Owen Harris  male  22.0
# 4              5         0       3       Allen, Mr. William Henry  male  35.0
# 6              7         0       1        McCarthy, Mr. Timothy J  male  54.0
# 13            14         0       3    Andersson, Mr. Anders Johan  male  39.0
# 20            21         0       2           Fynney, Mr. Joseph J  male  35.0
# ..           ...       ...     ...                            ...   ...   ...
# 883          884         0       2  Banfield, Mr. Frederick James  male  28.0
# 884          885         0       3         Sutehall, Mr. Henry Jr  male  25.0
# 886          887         0       2          Montvila, Rev. Juozas  male  27.0
# 889          890         1       1          Behr, Mr. Karl Howell  male  26.0
# 890          891         0       3            Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
#using np.where
import numpy as np
np.where(df.Fare==max(df.Fare))
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
#how to extract the data from array locations
#use of loc and iloc

# %%
#using iloc: it takes the index values
df.iloc[np.where(df.Fare==max(df.Fare))]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
#df.iloc[lowerbound_index:upperbound_index:stepsize,lowerbound_column:upperbound_column:stepsize]
df.iloc[0:10:2,1:4:2]
# Out:
#    Survived                                               Name
# 0         0                            Braund, Mr. Owen Harris
# 2         1                             Heikkinen, Miss. Laina
# 4         0                           Allen, Mr. William Henry
# 6         0                            McCarthy, Mr. Timothy J
# 8         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)

# %%
df.iloc[0:10:2,[1,4]]
# Out:
#    Survived     Sex
# 0         0    male
# 2         1  female
# 4         0    male
# 6         0    male
# 8         1  female

# %%
df.loc[0:10:2,'PassengerId':'Parch']
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 6             7         0       1
# 8             9         1       3
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch
# 0       0
# 2       0
# 4       0
# 6       0
# 8       2
# 10      1

# %%
#.loc takes the absolute values
df.loc[0:10:2,['PassengerId','Parch']]
# Out:
#     PassengerId  Parch
# 0             1      0
# 2             3      0
# 4             5      0
# 6             7      0
# 8             9      2
# 10           11      1

# %%
#sorting values
df['Fare'].sort_values(ascending=False)
# Out:
# 679    512.3292
# 258    512.3292
# 737    512.3292
# 341    263.0000
# 438    263.0000
#          ...
# 277      0.0000
# 633      0.0000
# 302      0.0000
# 597      0.0000
# 271      0.0000
# Name: Fare, Length: 891, dtype: float64

# %%
df['Fare'].sort_values()
# Out:
# 271      0.0000
# 597      0.0000
# 302      0.0000
# 633      0.0000
# 277      0.0000
#          ...
# 438    263.0000
# 341    263.0000
# 737    512.3292
# 258    512.3292
# 679    512.3292
# Name: Fare, Length: 891, dtype: float64

# %%
df.sort_values('Fare',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
# converting datatype of a columns
df.dtypes
# Out:
# PassengerId               int64
# Survived                 object
# Pclass                    int64
# Name                     object
# Sex                      object
# Age                     float64
# SibSp                     int64
# Parch                     int64
# Ticket                   object
# Fare                    float64
# Cabin                    object
# Embarked                 object
# Total Family Members      int64
# Family present           object
# dtype: object

# %%
type(df['Total Family Members'][0])
# Out:
# numpy.int64

# %%
df['Total Family Members']= df['Total Family Members'].astype(str)

# %%
df.dtypes
# Out:
# PassengerId               int64
# Survived                 object
# Pclass                    int64
# Name                     object
# Sex                      object
# Age                     float64
# SibSp                     int64
# Parch                     int64
# Ticket                   object
# Fare                    float64
# Cabin                    object
# Embarked                 object
# Total Family Members     object
# Family present           object
# dtype: object

# %%
df['Total Family Members']= df['Total Family Members'].astype(int)
df.dtypes
# Out:
# PassengerId               int64
# Survived                 object
# Pclass                    int64
# Name                     object
# Sex                      object
# Age                     float64
# SibSp                     int64
# Parch                     int64
# Ticket                   object
# Fare                    float64
# Cabin                    object
# Embarked                 object
# Total Family Members      int32
# Family present           object
# dtype: object

# %%
#mapping

# %%
dict1={1:2,2:2,3:4}

# %%
list1=[1,2,3,4,5]

# %%
pd.DataFrame(list1)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
pd.DataFrame(dict1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-61e7200a0cc7> in <module>
# ----> 1 pd.DataFrame(dict1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ...

# %%
pd.DataFrame(dict1, index=[1])
# Out:
#    1  2  3
# 1  2  2  4

# %%
dict2={1:[2,3,4,5],2:[2,4,3,2],3:[4,1,3,4]}

# %%
pd.DataFrame(dict2)
# Out:
#    1  2  3
# 0  2  2  4
# 1  3  4  1
# 2  4  3  3
# 3  5  2  4

# %%
dict3={1:[2,3,4,5],2:[2,4,3,2],3:[4,1,3,4,2]}

# %%
pd.DataFrame(dict3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-a2b9baa333a6> in <module>
# ----> 1 pd.DataFrame(dict3)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ...

# %%
#transpose operation
pd.DataFrame(dict2).T
# Out:
#    0  1  2  3
# 1  2  3  4  5
# 2  2  4  3  2
# 3  4  1  3  4

# %%
dict={'emp1':{'name':'Utkarsh','age':32,'profession':'data scientist'},'emp2':{'name':'Utkarsh2','age':32,'profession':'data scientist2'},'emp3':{'name':'Utkarsh3','age':32,'profession':'data scientist3'}}

# %%
pd.DataFrame(dict)
# Out:
#                       emp1             emp2             emp3
# name               Utkarsh         Utkarsh2         Utkarsh3
# age                     32               32               32
# profession  data scientist  data scientist2  data scientist3

# %%
#mapping columns
df['Survived'].map({0:'Drowned',1:'Survived'})
# Out:
# 0       Drowned
# 1      Survived
# 2      Survived
# 3      Survived
# 4       Drowned
#          ...
# 886     Drowned
# 887    Survived
# 888     Drowned
# 889    Survived
# 890     Drowned
# Name: Survived, Length: 891, dtype: object

# %%
#changing the data inside a column
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Survived']=df['Survived'].map({0:'Drowned',1:'Survived'})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1   Drowned       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5   Drowned       3
# ..           ...       ...     ...
# 886          887   Drowned       2
# 887          888  Survived       1
# 888          889   Drowned       3
# 889          890  Survived       1
# 890          891   Drowned       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
for x in df['Survived']:
    print(x)
# Out:
# Drowned
# Survived
# Survived
# Survived
# Drowned
# Drowned
# Drowned
# Drowned
# Survived
# Survived
# Survived
# Survived
# Drowned
# Drowned
# Drowned
# Survived
# Drowned
# Survived
# Drowned
# Survived
# Drowned
# Survived
# Survived
# Survived
# Drowned
# Survived
# Drowned
# Drowned
# Survived
# Drowned
# Drowned
# Survived
# Survived
# Drowned
# Drowned
# Drowned
# Survived
# Drowned
# Drowned
# Survived
# Drowned
# Drowned
# Drowned
# Survived
# Survived
# Drowned
# Drowned
# Survived
# Drowned
# Drowned
# Drowned
# Drowned
# Survived
# Survived
# Drowned
# Survived
# Survived
# Drowned
# Survived
# Drowned
# Drowned
# Survived
# Drowned
# Drowned
# Drowned
# Survived
# Survived
# Drowned
# Survived
# Drowned
# Drowned
# Drowned
# Drowned
# Drowned
# Survived
# Drowned
# Drowned
# Drowned
# Survived
# Survived
# Drowned
# Survived
# Survived
# Drowned
# Survived
# Survived
# Drowned
# Drowned
# Survived
# Drowned
# Drowned
# Drowned
# Drowned
# Drowned
# Drowned
# Drowned
# ...

# %%
# adding 2 columns
df['SibSp']+df['Parch']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Length: 891, dtype: int64

# %%
df['Total Family Members']=df['SibSp']+df['Parch']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1   Drowned       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5   Drowned       3
# ..           ...       ...     ...
# 886          887   Drowned       2
# 887          888  Survived       1
# 888          889   Drowned       3
# 889          890  Survived       1
# 890          891   Drowned       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
for x in range(df.shape[0]):
    if df['Total Family Members'][x]>0:
        df['Family present'][x]='Yes'
    else:
        df['Family present'][x]='No'
# Out:
# C:\Users\utkarsh\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\utkarsh\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1   Drowned       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5   Drowned       3
# ..           ...       ...     ...
# 886          887   Drowned       2
# 887          888  Survived       1
# 888          889   Drowned       3
# 889          890  Survived       1
# 890          891   Drowned       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#creating series
series_default_idx=pd.Series(np.arange(0,100))

# %%
#creating series with custom indexes
series_custom_idx=pd.Series(np.arange(0,100), index= np.arange(100,200))

# %%
series_custom_idx.iloc[0:10]
# Out:
# 100    0
# 101    1
# 102    2
# 103    3
# 104    4
# 105    5
# 106    6
# 107    7
# 108    8
# 109    9
# dtype: int32

# %%
series_custom_idx.loc[0:10]
# Out:
# Series([], dtype: int32)

# %%
series_custom_idx.loc[100:110]
# Out:
# 100     0
# 101     1
# 102     2
# 103     3
# 104     4
# 105     5
# 106     6
# 107     7
# 108     8
# 109     9
# 110    10
# dtype: int32

# %%
#Series addition operation

# %%
series_custom_idx+series_custom_idx
# Out:
# 100      0
# 101      2
# 102      4
# 103      6
# 104      8
#       ...
# 195    190
# 196    192
# 197    194
# 198    196
# 199    198
# Length: 100, dtype: int32

# %%
series_default_idx+series_custom_idx
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 195   NaN
# 196   NaN
# 197   NaN
# 198   NaN
# 199   NaN
# Length: 200, dtype: float64

# %%
#Dropping a row and reassigning indexes
df.drop(4,axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1   Drowned       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 5              6   Drowned       3
# ..           ...       ...     ...
# 886          887   Drowned       2
# 887          888  Survived       1
# 888          889   Drowned       3
# 889          890  Survived       1
# 890          891   Drowned       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_dropped=df.drop(4,axis=0)

# %%
df_dropped
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1   Drowned       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 5              6   Drowned       3
# ..           ...       ...     ...
# 886          887   Drowned       2
# 887          888  Survived       1
# 888          889   Drowned       3
# 889          890  Survived       1
# 890          891   Drowned       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#reseting the indexes
df_dropped.reset_index()
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1   Drowned       3
# 1        1            2  Survived       1
# 2        2            3  Survived       3
# 3        3            4  Survived       1
# 4        5            6   Drowned       3
# ..     ...          ...       ...     ...
# 885    886          887   Drowned       2
# 886    887          888  Survived       1
# 887    888          889   Drowned       3
# 888    889          890  Survived       1
# 889    890          891   Drowned       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
#reseting indexes without creating a new column
df_dropped.reset_index(drop=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1   Drowned       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              6   Drowned       3
# ..           ...       ...     ...
# 885          887   Drowned       2
# 886          888  Survived       1
# 887          889   Drowned       3
# 888          890  Survived       1
# 889          891   Drowned       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#basic null value imputation
df.fillna(value='New Value')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1   Drowned       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5   Drowned       3
# ..           ...       ...     ...
# 886          887   Drowned       2
# 887          888  Survived       1
# 888          889   Drowned       3
# 889          890  Survived       1
# 890          891   Drowned       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male         22
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female         38
# 2                               Heikkinen, Miss. Laina  female         26
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female         35
# 4                             Allen, Mr. William Henry    male         35
# ..                                                 ...     ...        ...
# ...

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2  Survived       1
# 3              4  Survived       1
# 6              7   Drowned       1
# 10            11  Survived       3
# 11            12  Survived       1
# ..           ...       ...     ...
# 871          872  Survived       1
# 872          873   Drowned       1
# 879          880  Survived       1
# 887          888  Survived       1
# 889          890  Survived       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(thresh=2,axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1   Drowned       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5   Drowned       3
# ..           ...       ...     ...
# 886          887   Drowned       2
# 887          888  Survived       1
# 888          889   Drowned       3
# 889          890  Survived       1
# 890          891   Drowned       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1   Drowned       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5   Drowned       3
# ..           ...       ...     ...
# 886          887   Drowned       2
# 887          888  Survived       1
# 888          889   Drowned       3
# 889          890  Survived       1
# 890          891   Drowned       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
#exploring iloc further to extract data

# %%
df.iloc[[4,886,887],[3,9]]
# Out:
#                              Name   Fare
# 4        Allen, Mr. William Henry   8.05
# 886         Montvila, Rev. Juozas  13.00
# 887  Graham, Miss. Margaret Edith  30.00

# %%
df.loc[[4,886,887],['Name','Fare']]
# Out:
#                              Name   Fare
# 4        Allen, Mr. William Henry   8.05
# 886         Montvila, Rev. Juozas  13.00
# 887  Graham, Miss. Margaret Edith  30.00

# %%
df.groupby('Sex').sum()
# Out:
#         PassengerId  Pclass       Age  SibSp  Parch        Fare  \
# Sex
# female       135343     678   7286.00    218    204  13966.6628
# male         262043    1379  13919.17    248    136  14727.2865
#
#         Total Family Members
# Sex
# female                   422
# male                     384

# %%
df.groupby('Sex')['Survived'].value_counts()
# Out:
# Sex     Survived
# female  Survived    233
#         Drowned      81
# male    Drowned     468
#         Survived    109
# Name: Survived, dtype: int64
